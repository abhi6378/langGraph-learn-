# %%
from typing import TypeDict, List
from typing import TypedDict, List
from langgraph.graph import StateGraph  # noqa: F401
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from typing import TypeDict, List
#       2 from langgraph.graph import StateGraph  # noqa: F401
#
# ImportError: cannot import name 'TypeDict' from 'typing' (c:\Users\lenovo\AppData\Local\Programs\Python\Python312\Lib\typing.py)

# %%
class AgentState(TypedDict):
    values: List[int]
    name : str
    result: str
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 class AgentState(TypedDict):
#       2     values: List[int]
#       3     name : str
#       4     result: str
#
# NameError: name 'TypedDict' is not defined
